# %%
import polars as pl
from datasets import load_dataset

# %%
markets = pl.read_parquet('data/processed/markets_political.parquet')

# %%
desired_markets = markets['condition_id'].to_list()

# %%
# Stream just the first batch to check schema and content
dataset = load_dataset(
    "SII-WANGZJ/Polymarket_data",
    data_files="quant.parquet",
    streaming=True,
    split="train",
    filters=[("condition_id", "in", desired_markets)]
)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
rows = []
for i,x in enumerate(dataset):
    rows.append(x)
    if i % 1000 == 0:
        print(f"Loaded {i} rows")

    if i == 999_000:
        break
# Out:
# Loaded 0 amount of rows
# Loaded 1000 amount of rows
# Loaded 2000 amount of rows
# Loaded 3000 amount of rows
# Loaded 4000 amount of rows
# Loaded 5000 amount of rows
# Loaded 6000 amount of rows
# Loaded 7000 amount of rows
# Loaded 8000 amount of rows
# Loaded 9000 amount of rows
# Loaded 10000 amount of rows
# Loaded 11000 amount of rows
# Loaded 12000 amount of rows
# Loaded 13000 amount of rows
# Loaded 14000 amount of rows
# Loaded 15000 amount of rows
# Loaded 16000 amount of rows
# Loaded 17000 amount of rows
# Loaded 18000 amount of rows
# Loaded 19000 amount of rows
# Loaded 20000 amount of rows
# Loaded 21000 amount of rows
# Loaded 22000 amount of rows
# Loaded 23000 amount of rows
# Loaded 24000 amount of rows
# Loaded 25000 amount of rows
# Loaded 26000 amount of rows
# Loaded 27000 amount of rows
# Loaded 28000 amount of rows
# Loaded 29000 amount of rows
# Loaded 30000 amount of rows
# Loaded 31000 amount of rows
# Loaded 32000 amount of rows
# Loaded 33000 amount of rows
# Loaded 34000 amount of rows
# Loaded 35000 amount of rows
# Loaded 36000 amount of rows
# Loaded 37000 amount of rows
# Loaded 38000 amount of rows
# Loaded 39000 amount of rows
# Loaded 40000 amount of rows
# Loaded 41000 amount of rows
# Loaded 42000 amount of rows
# Loaded 43000 amount of rows
# Loaded 44000 amount of rows
# Loaded 45000 amount of rows
# Loaded 46000 amount of rows
# Loaded 47000 amount of rows
# Loaded 48000 amount of rows
# Loaded 49000 amount of rows
# Loaded 50000 amount of rows
# Loaded 51000 amount of rows
# Loaded 52000 amount of rows
# Loaded 53000 amount of rows
# Loaded 54000 amount of rows
# Loaded 55000 amount of rows
# Loaded 56000 amount of rows
# Loaded 57000 amount of rows
# Loaded 58000 amount of rows
# Loaded 59000 amount of rows
# Loaded 60000 amount of rows
# Loaded 61000 amount of rows
# Loaded 62000 amount of rows
# Loaded 63000 amount of rows
# Loaded 64000 amount of rows
# Loaded 65000 amount of rows
# Loaded 66000 amount of rows
# Loaded 67000 amount of rows
# Loaded 68000 amount of rows
# Loaded 69000 amount of rows
# Loaded 70000 amount of rows
# Loaded 71000 amount of rows
# Loaded 72000 amount of rows
# Loaded 73000 amount of rows
# Loaded 74000 amount of rows
# Loaded 75000 amount of rows
# Loaded 76000 amount of rows
# Loaded 77000 amount of rows
# Loaded 78000 amount of rows
# Loaded 79000 amount of rows
# Loaded 80000 amount of rows
# Loaded 81000 amount of rows
# Loaded 82000 amount of rows
# Loaded 83000 amount of rows
# Loaded 84000 amount of rows
# Loaded 85000 amount of rows
# Loaded 86000 amount of rows
# Loaded 87000 amount of rows
# Loaded 88000 amount of rows
# Loaded 89000 amount of rows
# Loaded 90000 amount of rows
# Loaded 91000 amount of rows
# Loaded 92000 amount of rows
# Loaded 93000 amount of rows
# Loaded 94000 amount of rows
# Loaded 95000 amount of rows
# Loaded 96000 amount of rows
# Loaded 97000 amount of rows
# Loaded 98000 amount of rows
# Loaded 99000 amount of rows
# Loaded 100000 amount of rows
# Loaded 101000 amount of rows
# Loaded 102000 amount of rows
# Loaded 103000 amount of rows
# Loaded 104000 amount of rows
# Loaded 105000 amount of rows
# Loaded 106000 amount of rows
# Loaded 107000 amount of rows
# Loaded 108000 amount of rows
# Loaded 109000 amount of rows
# Loaded 110000 amount of rows
# Loaded 111000 amount of rows
# Loaded 112000 amount of rows
# Loaded 113000 amount of rows
# Loaded 114000 amount of rows
# Loaded 115000 amount of rows
# Loaded 116000 amount of rows
# Loaded 117000 amount of rows
# Loaded 118000 amount of rows
# Loaded 119000 amount of rows
# Loaded 120000 amount of rows
# Loaded 121000 amount of rows
# Loaded 122000 amount of rows
# Loaded 123000 amount of rows
# Loaded 124000 amount of rows
# Loaded 125000 amount of rows
# Loaded 126000 amount of rows
# Loaded 127000 amount of rows
# Loaded 128000 amount of rows
# Loaded 129000 amount of rows
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[119], line 2
#       1 rows = []
# ----> 2 for i,x in enumerate(dataset):
#       3     rows.append(x)
#       4     if i % 1000 == 0:
#
# File ~/miniconda3/envs/poly/lib/python3.11/site-packages/datasets/iterable_dataset.py:2690, in IterableDataset.__iter__(self)
#    2687         yield formatter.format_row(pa_table)
#    2688     return
# -> 2690 for key, example in ex_iterable:
#    2691     # no need to format thanks to FormattedExamplesIterable
#    2692     yield example
#
# File ~/miniconda3/envs/poly/lib/python3.11/site-packages/datasets/iterable_dataset.py:2228, in FormattedExamplesIterable.__iter__(self)
#    2225 if self.ex_iterable.iter_arrow:
#    2226     # feature casting (inc column addition) handled within self._iter_arrow()
#    2227     for key, pa_table in self._iter_arrow():
# -> 2228         batch = formatter.format_batch(pa_table)
#    2229         for example in _batch_to_examples(batch):
#    2230             yield key, example
#
# File ~/miniconda3/envs/poly/lib/python3.11/site-packages/datasets/formatting/formatting.py:471, in PythonFormatter.format_batch(self, pa_table)
#     469 if self.lazy:
#     470     return LazyBatch(pa_table, self)
# --> 471 batch = self.python_arrow_extractor().extract_batch(pa_table)
#     472 batch = self.python_features_decoder.decode_batch(batch)
#     473 return batch
#
# File ~/miniconda3/envs/poly/lib/python3.11/site-packages/datasets/formatting/formatting.py:150, in PythonArrowExtractor.extract_batch(self, pa_table)
#     149 def extract_batch(self, pa_table: pa.Table) -> dict:
# --> 150     return pa_table.to_pydict()
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 len(dataset)
#
# TypeError: object of type 'IterableDataset' has no len()

# %%
sample = pl.DataFrame(rows)

# %%
sample
# Out:
# shape: (1_000, 13)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────────┬──────┬───────────┬───────────┐
# │ timestamp  ┆ block_numb ┆ transactio ┆ log_index ┆ … ┆ token_amou ┆ side ┆ maker     ┆ taker     │
# │ ---        ┆ er         ┆ n_hash     ┆ ---       ┆   ┆ nt         ┆ ---  ┆ ---       ┆ ---       │
# │ i64        ┆ ---        ┆ ---        ┆ i64       ┆   ┆ ---        ┆ str  ┆ str       ┆ str       │
# │            ┆ i64        ┆ str        ┆           ┆   ┆ f64        ┆      ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════════╪══════╪═══════════╪═══════════╡
# │ 1669060169 ┆ 35896869   ┆ 05a7f9b0b0 ┆ 204       ┆ … ┆ 100.0      ┆ SELL ┆ 0xEA5981C ┆ 0xEA5981C │
# │            ┆            ┆ 16d7e431b4 ┆           ┆   ┆            ┆      ┆ A48Dc40C9 ┆ A48Dc40C9 │
# │            ┆            ┆ e62b374870 ┆           ┆   ┆            ┆      ┆ 50fC1B249 ┆ 50fC1B249 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6c4…      ┆ 6c4…      │
# │ 1669060373 ┆ 35896929   ┆ 3a5412c9d8 ┆ 161       ┆ … ┆ 100.0      ┆ SELL ┆ 0xEA5981C ┆ 0xEA5981C │
# │            ┆            ┆ 129e8a27dd ┆           ┆   ┆            ┆      ┆ A48Dc40C9 ┆ A48Dc40C9 │
# │            ┆            ┆ b43cdf60ad ┆           ┆   ┆            ┆      ┆ 50fC1B249 ┆ 50fC1B249 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6c4…      ┆ 6c4…      │
# │ 1669060582 ┆ 35897058   ┆ 4541524b5b ┆ 189       ┆ … ┆ 10.0       ┆ SELL ┆ 0xEA5981C ┆ 0xEA5981C │
# │            ┆            ┆ 2f910c9f3f ┆           ┆   ┆            ┆      ┆ A48Dc40C9 ┆ A48Dc40C9 │
# │            ┆            ┆ 5d12feae26 ┆           ┆   ┆            ┆      ┆ 50fC1B249 ┆ 50fC1B249 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6c4…      ┆ 6c4…      │
# │ 1669060582 ┆ 35897058   ┆ b6dadd061a ┆ 180       ┆ … ┆ 10.0       ┆ SELL ┆ 0xEA5981C ┆ 0xEA5981C │
# │            ┆            ┆ 1b4fa4a46b ┆           ┆   ┆            ┆      ┆ A48Dc40C9 ┆ A48Dc40C9 │
# │            ┆            ┆ e4f235db01 ┆           ┆   ┆            ┆      ┆ 50fC1B249 ┆ 50fC1B249 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6c4…      ┆ 6c4…      │
# │ 1669060582 ┆ 35897058   ┆ e444cffd29 ┆ 170       ┆ … ┆ 10.0       ┆ SELL ┆ 0xEA5981C ┆ 0xEA5981C │
# │            ┆            ┆ 4164908e48 ┆           ┆   ┆            ┆      ┆ A48Dc40C9 ┆ A48Dc40C9 │
# │            ┆            ┆ 62b1859ea5 ┆           ┆   ┆            ┆      ┆ 50fC1B249 ┆ 50fC1B249 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6c4…      ┆ 6c4…      │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …          ┆ …    ┆ …         ┆ …         │
# │ 1674652100 ┆ 38509827   ┆ 7ef9b37801 ┆ 164       ┆ … ┆ 500.0      ┆ SELL ┆ 0xF6129C4 ┆ 0xF6129C4 │
# │            ┆            ┆ aa20389674 ┆           ┆   ┆            ┆      ┆ 7F5ef4cAb ┆ 7F5ef4cAb │
# │            ┆            ┆ fd20c74239 ┆           ┆   ┆            ┆      ┆ 25F3aA67b ┆ 25F3aA67b │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 5E3…      ┆ 5E3…      │
# │ 1674668820 ┆ 38517686   ┆ 0c7795d278 ┆ 256       ┆ … ┆ 746.27     ┆ SELL ┆ 0xe8E46bD ┆ 0x569E37d │
# │            ┆            ┆ 3ff9f20d78 ┆           ┆   ┆            ┆      ┆ B46513Ffa ┆ e70cFc302 │
# │            ┆            ┆ 2b7eb22a8a ┆           ┆   ┆            ┆      ┆ 330656430 ┆ 405Dc0577 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 3F3…      ┆ AE4…      │
# │ 1674684997 ┆ 38524817   ┆ 46ad589515 ┆ 198       ┆ … ┆ 74.63      ┆ SELL ┆ 0xe8E46bD ┆ 0x69EF36e │
# │            ┆            ┆ 5cabf50f66 ┆           ┆   ┆            ┆      ┆ B46513Ffa ┆ 0D158FDbB │
# │            ┆            ┆ a2f0c0bfbd ┆           ┆   ┆            ┆      ┆ 330656430 ┆ 45dD48e3f │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 3F3…      ┆ C16…      │
# │ 1674608240 ┆ 38489536   ┆ f3953b6939 ┆ 572       ┆ … ┆ 500.0      ┆ BUY  ┆ 0x30E4438 ┆ 0xE2B1FC2 │
# │            ┆            ┆ 77a33c595b ┆           ┆   ┆            ┆      ┆ 72dDf63B2 ┆ 69d0c2E27 │
# │            ┆            ┆ b435d33048 ┆           ┆   ┆            ┆      ┆ 908a49f92 ┆ dA11fADD1 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ cd6…      ┆ d95…      │
# │ 1674657418 ┆ 38512380   ┆ 10bab9c0db ┆ 228       ┆ … ┆ 0.01       ┆ SELL ┆ 0x8A4c788 ┆ 0xe8E46bD │
# │            ┆            ┆ 4a2f388aca ┆           ┆   ┆            ┆      ┆ F043023b8 ┆ B46513Ffa │
# │            ┆            ┆ 230a5f5169 ┆           ┆   ┆            ┆      ┆ B28a76221 ┆ 330656430 │
# │            ┆            ┆ …          ┆           ┆   ┆            ┆      ┆ 6d0…      ┆ 3F3…      │
# └────────────┴────────────┴────────────┴───────────┴───┴────────────┴──────┴───────────┴───────────┘
